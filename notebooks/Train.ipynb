# %% [markdown]
# # Train — RetinaScan
#
# Full training pipeline in Colab T4

# %%
# Mount Drive & Check GPU
from google.colab import drive
drive.mount('/content/drive')
# !nvidia-smi

# %%
# Clone repo
# !git clone https://github.com/YOUR_USER/RetinaScan.git
# %cd RetinaScan

# %%
# Install deps
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# !pip install open-clip-torch opencv-python scikit-image scikit-learn tqdm pyyaml matplotlib seaborn

# %%
# Download EyePACS via Kaggle
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c diabetic-retinopathy-detection -p data/raw/
# !unzip -q 'data/raw/diabetic-retinopathy-detection.zip' -d data/raw/

# %%
# Preprocess
# !python src/preprocess.py --config configs/train_config.yaml

# %%
# Train (~3h on T4)
# !python src/train.py --config configs/train_config.yaml

# %%
# Save to Drive
# !cp -r checkpoints /content/drive/MyDrive/RetinaScan/
